# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Projectos\Python-ETL\data\raw\RestaurantSales.xlsx")
df.head(10)
# Out:
#   Transaction ID Order Date    Restaurant Location Order Type  \
# 0      RST-30001 2024-07-05           Coral Gables   Delivery
# 1      RST-30002 2024-09-22           Chicago Loop   Takeaway
# 2      RST-30003 2025-04-20           Midtown East   Takeaway
# 3      RST-30004 2024-06-28           Lincoln Park   Delivery
# 4      RST-30005 2025-07-05  Austin South Congress    Dine-In
# 5      RST-30006 2025-05-15     Downtown Manhattan   Delivery
# 6      RST-30007 2024-05-26            Miami Beach    Dine-In
# 7      RST-30008 2025-11-22     Downtown Manhattan   Takeaway
# 8      RST-30009 2024-10-10        Upper West Side    Dine-In
# 9      RST-30010 2024-12-28  Austin South Congress    Dine-In
#
#           Menu Item   Category  Quantity  Unit Price  Order Total  \
# 0  Chicken Parmesan       Main         2       18.99        37.98
# 1        House Wine   Beverage         1        9.99         9.99
# 2   Soup of the Day  Appetizer         3        8.99        26.97
# ...

# %%
# calc- localizar o 1 item especifico de uma coluna
df_cal = df.loc[df["Restaurant Location"] == 'Chicago Loop']

# %%
df_cal

# %%
itens = ['Austin South Congress', 'Upper West Side','Miami beach' ]
df_itens = df.loc[df['Restaurant Location'].isin(itens)]

# %%
df_itens.head()

# %%
# localizar valor > que o que escolher
dfMais100 = df.loc[df["Unit Price"] > 10]

# %%
dfMais100.head()

# %%
df20a10 = df.loc[(df["Unit Price"] > 10) & (df["Unit Price"] < 20) ]

# %%
df20a10.head()
# Out:
#    Transaction ID Order Date    Restaurant Location Order Type  \
# 0       RST-30001 2024-07-05           Coral Gables   Delivery
# 6       RST-30007 2024-05-26            Miami Beach    Dine-In
# 7       RST-30008 2025-11-22     Downtown Manhattan   Takeaway
# 9       RST-30010 2024-12-28  Austin South Congress    Dine-In
# 10      RST-30011 2025-05-09           Coral Gables    Dine-In
#
#            Menu Item   Category  Quantity  Unit Price  Order Total  \
# 0   Chicken Parmesan       Main         2       18.99        37.98
# 6   Chicken Parmesan       Main         1       18.99        18.99
# 7   Mushroom Risotto       Main         2       16.99        33.98
# 9       Caesar Salad  Appetizer         1       12.99        12.99
# 10        Bruschetta  Appetizer         2       11.99        23.98
#
#     Customer Rating
# 0                 4
# 6                 4
# 7                 4
# 9                 3
# 10                5
