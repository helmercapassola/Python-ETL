# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Projectos\Python-ETL\data\raw\EmployeeRH.csv", delimiter=';')
df.head(10)
# Out:
#   Employee ID          Full Name  Gender        Department  \
# 0    EMP-1001  Richard Hernandez    Male             Sales
# 1    EMP-1002     Richard Harris    Male        Operations
# 2    EMP-1003  Timothy Rodriguez    Male             Sales
# 3    EMP-1004       Amanda Young  Female         Marketing
# 4    EMP-1005        Nancy Clark  Female           Finance
# 5    EMP-1006   William Williams    Male       Engineering
# 6    EMP-1007       Laura Garcia  Female       Engineering
# 7    EMP-1008       Mary Jackson  Female  Customer Support
# 8    EMP-1009        Laura Allen  Female         Marketing
# 9    EMP-1010      Stephanie Lee  Female        Operations
#
#                       Job Title   Hire Date Annual Salary  Performance Rating  \
# 0          Sales Representative  02/12/2023       $85 100                   2
# 1          Warehouse Supervisor  11/04/2020       $54 900                   5
# 2          Sales Representative  10/06/2017       $80 200                   4
# 3         Marketing Coordinator  03/09/2018       $63 300                   4
# 4             Financial Analyst  04/28/2016       $61 400                   3
# 5             Software Engineer  01/31/2018      $101 800                   4
# 6                    QA Analyst  01/31/2021       $86 300                   4
# 7  Technical Support Specialist  10/08/2017       $59 000                   2
# 8                 Brand Manager  12/28/2015      $120 900                   3
# 9      Process Improvement Lead  02/07/2023       $78 600                   3
#
#    Satisfaction Score Employment Status
# 0                   3            Active
# 1                   6            Active
# 2                   5            Active
# 3                   6            Active
# 4                   3          Resigned
# 5                   5            Active
# 6                   6          Resigned
# 7                   2          Resigned
# 8                   4            Active
# 9                   3            Active

# %%
#filtrar 1 item especifico de uma coluna
departament = df.loc[df['Department'] == 'Finance']
departament.head()
# Out:
#    Employee ID         Full Name  Gender Department          Job Title  \
# 4     EMP-1005       Nancy Clark  Female    Finance  Financial Analyst
# 16    EMP-1017       Mary Walker  Female    Finance  Financial Analyst
# 24    EMP-1025  George Hernandez    Male    Finance         Accountant
# 36    EMP-1037     Matthew Brown    Male    Finance     Budget Manager
# 38    EMP-1039      Ashley Lewis  Female    Finance     Budget Manager
#
#      Hire Date Annual Salary  Performance Rating  Satisfaction Score  \
# 4   04/28/2016       $61 400                   3                   3
# 16  08/27/2016       $81 200                   5                   8
# 24  03/22/2023       $60 600                   4                   6
# 36  04/06/2021      $142 900                   4                   8
# 38  09/28/2021       $95 900                   4                   6
#
#    Employment Status
# 4           Resigned
# 16            Active
# 24            Active
# 36            Active
# 38            Active

# %%
# Número de departamentos 
len(departament)
# Out:
# 137

# %%
# escolher departamento específicos
departaments = ['Sales','Operation','Marketing','Engineering']
#Filtrar apenas as linhas onde o departamento está na lista
df_departaments = df.loc[df['Department'].isin(departaments)]
df_departaments.head()
# Out:
#   Employee ID          Full Name  Gender   Department              Job Title  \
# 0    EMP-1001  Richard Hernandez    Male        Sales   Sales Representative
# 2    EMP-1003  Timothy Rodriguez    Male        Sales   Sales Representative
# 3    EMP-1004       Amanda Young  Female    Marketing  Marketing Coordinator
# 5    EMP-1006   William Williams    Male  Engineering      Software Engineer
# 6    EMP-1007       Laura Garcia  Female  Engineering             QA Analyst
#
#     Hire Date Annual Salary  Performance Rating  Satisfaction Score  \
# 0  02/12/2023       $85 100                   2                   3
# 2  10/06/2017       $80 200                   4                   5
# 3  03/09/2018       $63 300                   4                   6
# 5  01/31/2018      $101 800                   4                   5
# 6  01/31/2021       $86 300                   4                   6
#
#   Employment Status
# 0            Active
# 2            Active
# 3            Active
# 5            Active
# 6          Resigned
