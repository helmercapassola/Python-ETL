# %%
qtd=5
type(qtd)
# Out:
# int

# %%
pc_produto = 100.50
type(pc_produto)
# Out:
# float

# %%
nome = "Helmer Capassola"
type(nome)
# Out:
# str

# %%
verificar = (True)
type(verificar)
# Out:
# bool
