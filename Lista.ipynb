# %%
#criando lista vazia
lista_vazia = []
lista_vazia2 = list()

# %% [markdown]
# #Visualizar Lista

# %%
type(lista_vazia)
# Out:
# list

# %%
type(lista_vazia2)
# Out:
# list

# %%
#tamanho da lista
len(lista_vazia)
# Out:
# 3

# %%
#Lista de elementos 
lista = [33,44,-6,56,79]
lista_float = [1.5, -4.6, 5.5, -4.5]
lista_string = ["Luanda", "Icole Bengo", "Cacuaco", "Viana"]
lista_boolean = [True, False, True, False]
lista_mista = ["Luanda", 123, 4.43, "Luanda"]
lista_mista2 = [2,4,5,8, -10, "Prenda", [1, "A", 1.0]]
lista_alinhadas = [[1,3,4,5,6], [3,5,-4,5,55]]

# %% [markdown]
# #Vizualizar elementos de uma lista

# %%
lista
# Out:
# [33, 44, -6, 56, 79]

# %%
# Acessar o indice e (primeira posição)
lista[0]
# Out:
# 33

# %%
lista_mista2[6][2]
# Out:
# 1.0
